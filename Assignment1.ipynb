# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Junjie Xia
#
# Student ID: 1045673

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 27 March 2022 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -10% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See "Using Jupyter Notebook and Python" page on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=https://www.nltk.org/book/>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection of tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation (based on frequency). The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English alphabets (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet (represented using a python dictionary). For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import re
from collections import Counter

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase

def preprocess_data(data, labels):
    
    ###
    # Your answer BEGINS HERE
    ###
    number = 0
    empty_list = []
    data_list = []
    for i in data:
    #data = ''.join(data)
        tokens = tt.tokenize(i)
        tokens = [token.lower() for token in tokens]
        tokens = [s for s in tokens if re.search(r'\w+', s)]
        tokens = [s for s in tokens if s not in stopwords]
        tokens = dict(Counter(tokens))
        if len(tokens) == 0:
            empty_list.append(number)
            continue
        else:
            data_list.append(tokens)
        number = number + 1
        #print(tokens)
    if len(empty_list) > 0:
        for i in empty_list:
            y.pop(int(i))
    #print(type(data))
    return data_list, y


    ###
    # Your answer ENDS HERE
    ###

x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = {'@addictd2success': 1, 'thx': 1, 'u': 1, 'following': 1}
# Country = us 	Tweet = {"let's": 1, 'say': 1, 'ever': 1, 'switch': 1, 'teams': 1, 'khalesi': 1, 'would': 1, 'top': 1, 'list': 1, '#girlcrush': 1}
# Country = ph 	Tweet = {'taemin': 1, 'jonghyun': 1, 'birits': 1, 'make': 1, 'go': 1, 'http://t.co/le8z3dntla': 1}
# Country = id 	Tweet = {'depart.senior': 1, 'rapat': 1, 'perdana': 1, 'nyayu': 1, 'anita': 1, '8': 1, 'others': 1, 'ruang': 1, 'aescullap': 1, 'fk': 1, 'unsri': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1}
# Country = ph 	Tweet = {'done': 1, 'internship': 1, 'pretty': 1, 'little': 1, 'lady': 1, 'metropolitan': 1, 'medical': 1, 'center': 1, 'w': 1, '3': 1, 'others': 1, 'pic': 1, 'http://t.co/1qh61r1t5r': 1}
# Country = gb 	Tweet = {'wow': 1, "boruc's": 1, 'clanger': 1, 'haha': 1, 'sunday': 1, 'league': 1, 'stuff': 1, 'giroud': 1, 'believe': 1, 'luck': 1, '#clown': 1}
# Country = my 	Tweet = {"i'm": 1, 'sushi': 1, 'zanmai': 1, 'petaling': 1, 'jaya': 1, 'selangor': 1, 'w': 1, '5': 1, 'others': 1, 'http://t.co/bcnobykz': 1}
# Country = us 	Tweet = {'mega': 1, 'fest': 1, 'going': 1, '@bishopjakes': 1}
# Country = gb 	Tweet = {'@ellexxxpharrell': 1, 'wow': 1, 'love': 1, 'pic': 1, 'babe': 1, 'xx': 1}
# Country = us 	Tweet = {'clue': 1, 'much': 1, 'hurt': 1}

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecord", the algorithm should produce: \["#", "new", "record"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
from nltk.corpus import wordnet

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words = set([ word.lower() for word in words ]) #lowercase all the words for better matching
#print(list(words))

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma

#reference:https://blog.csdn.net/weixin_40322587/article/details/80877810
def MaxMatch(sentence, dictonary):
    n = len(sentence)
    if sentence == '':
        return []
    for i in range(n):
        firstword = sentence[:n - i]
        reminder = sentence[n - i:]
        if firstword in dictonary:
            return [firstword] + MaxMatch(reminder, dictonary)
    #no words was found, so make one word
    firstword = sentence[0]
    reminder = sentence[1:]
    return [firstword] + MaxMatch(reminder, dictonary)

# def MaxMatch2(string, lowercaseCorpus):
#     tokens = []
#     i = 0
#     while i < len(string):
#         maxWord = ""
#         for j in range(i, len(string)):
#             tempWord = string[i:j+1]
#             if tempWord in lowercaseCorpus and len(tempWord) > len(maxWord):
#                 maxWord = tempWord
#         i = i+len(maxWord)
#     tokens.append(maxWord)
    
#     return tokens


# lemmatized_words=[]
# for j in words:
#     lemmatized_words.append(lemmatize(j))
# print(MaxMatch('se',lemmatized_words))

      #a=MaxMatch(sorted(hashtags[0]),sorted(words))
# for i in words:
#     a=lemmatize(i)
#     print(a)


def tokenize_hashtags(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    result = {}
    lemmatized_words=[]
    for j in words:
        lemmatized_words.append(lemmatize(j))
    for i in hashtags:
        separate = []
        separate.append('#')
        k=i[1:]
        separate = separate + MaxMatch(k, lemmatized_words)
        #separate = separate + MaxMatch2(k, lemmatized_words)
        #i = lemmatize(i)
        result[i] = separate
    return result


    ###
    # Your answer ENDS HERE
    ###


#tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

#print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetable', 's']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'v', 's', 'co']
# #vscocam ['#', 'v', 's', 'coca', 'm']
# #walking ['#', 'walk', 'ing']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e', '9', '0', 's']
# #wearesocial ['#', 'wear', 'es', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wing', 's']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mate', 's']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'yi', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'w', 's', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
#reference:https://blog.csdn.net/weixin_40322587/article/details/80877810
def backwordMaxmatching(sentence,dictonary):
    n = len(sentence)
    if sentence == '':
        return []
    for i in range(n):
        lastword = sentence[-(n - i):]
        reminder = sentence[:-(n - i)]
        if lastword in dictonary:
            return backwordMaxmatching(reminder, dictonary) + [lastword]
    #no words was found, so make one word
    lastword = sentence[-1]
    reminder = sentence[:-1]
    return backwordMaxmatching(reminder, dictonary) + [lastword]

#     res = []
#     sentence = sentence
#     len_sentence = len(sentence)
#     while len_sentence> 0:
#         #word = sentence[-max_length:]
#         word = sentence[-len_sentence:]
#         while word not in dic:
#             if len(word) == 1:
#                 break
#             word = word[-(len(word)-1):]
#         res.append(word)
#         sentence = sentence[:-len(word)]
#         len_sentence = len(sentence)
#     return res


def tokenize_hashtags_rev(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    result = {}
    lemmatized_words=[]
    for j in words:
        lemmatized_words.append(lemmatize(j))
    for i in hashtags:
        separate = []
        separate.append('#')
        k = i[1:]
#         middle = backwordMaxmatching(k, lemmatized_words)
#         if len(middle) == 0:
#             continue
#         else:
        separate = separate + backwordMaxmatching(k, lemmatized_words)
        result[i] = separate
    return result

    ###
    # Your answer ENDS HERE
    ###

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'g', 'an']
# #veganfood ['#', 'v', 'e', 'g', 'an', 'food']
# #vegetables ['#', 'v', 'e', 'ge', 'tab', 'l', 'es']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'v', 's', 'co']
# #vscocam ['#', 'v', 's', 'co', 'cam']
# #walking ['#', 'w', 'al', 'king']
# #watch ['#', 'watch']
# #weare90s ['#', 'wea', 're', '9', '0', 's']
# #wearesocial ['#', 'wea', 're', 'social']
# #white ['#', 'white']
# #wings ['#', 'wing', 's']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mat', 'es']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'yi', 'a', 'm', 'as']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'w', 's', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])
# print(tokenized_hashtags['#fotografías'])
# print(tokenized_hashtags_rev['#fotografías'])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i>) = P(<i>#</i>)\*P(<i>hellow</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
from collections import Counter
import math

#words from brown corpus
brown_words = brown.words()

###
# Your answer BEGINS HERE
###
brown_words = [token.lower() for token in brown_words]
brown_words_dict = dict(Counter(brown_words))
number = 0
for i in tokenized_hashtags_rev:
    if tokenized_hashtags[i] != tokenized_hashtags_rev[i]:
        number = number + 1
        print(number, '.', i)
        maxmatch_result = 1
        for j in tokenized_hashtags[i]:
            if j in brown_words_dict:
                maxmatch_result = maxmatch_result * (brown_words_dict[j]+1)/(len(brown_words)+len(tokenized_hashtags[i]))
            else:
                maxmatch_result = maxmatch_result * 1/(len(brown_words)+len(tokenized_hashtags[i]))
        print('MaxMatch =', tokenized_hashtags[i],'; LogProb =', math.log(maxmatch_result))
        rev_maxmatch_result = 1
        for j in tokenized_hashtags_rev[i]:
            if j in brown_words_dict:
                rev_maxmatch_result = rev_maxmatch_result * (brown_words_dict[j]+1)/(len(brown_words)+len(tokenized_hashtags_rev[i]))
            else:
                rev_maxmatch_result = rev_maxmatch_result * (1)/(len(brown_words)+len(tokenized_hashtags_rev[i]))
        print('Reversed MaxMatch =', tokenized_hashtags_rev[i],'; LogProb =', math.log(rev_maxmatch_result))
        print("")

# number=0
# for i in tokenized_hashtags_rev:
#     if tokenized_hashtags_rev[i] != tokenized_hashtags[i]:
#         number=number+1
#     else:
#         pass
# print(number)

#print(brown_words)
    
###
# Your answer ENDS HERE
###
# Out:
# 1 . #thomassabo
# MaxMatch = ['#', 'thomas', 'sab', 'o'] ; LogProb = -47.948886882811664
# Reversed MaxMatch = ['#', 'tho', 'mass', 'abo'] ; LogProb = -49.4729649462946
#
# 2 . #nickryrie
# MaxMatch = ['#', 'nick', 'r', 'yr', 'ie'] ; LogProb = -62.90315145382387
# Reversed MaxMatch = ['#', 'nick', 'r', 'y', 'rie'] ; LogProb = -61.11139198459581
#
# 3 . #shakes
# MaxMatch = ['#', 'shake', 's'] ; LogProb = -35.869014641873335
# Reversed MaxMatch = ['#', 's', 'hak', 'es'] ; LogProb = -52.7243500497281
#
# 4 . #thankyoupatients
# MaxMatch = ['#', 'thank', 'youp', 'ati', 'en', 't', 's'] ; LogProb = -84.57218305273625
# Reversed MaxMatch = ['#', 'thank', 'you', 'patient', 's'] ; LogProb = -50.51475881708282
#
# 5 . #veganfood
# MaxMatch = ['#', 'vega', 'n', 'food'] ; LogProb = -47.19907034576349
# Reversed MaxMatch = ['#', 'v', 'e', 'g', 'an', 'food'] ; LogProb = -60.686466303601684
#
# 6 . #rose
# MaxMatch = ['#', 'ro', 'se'] ; LogProb = -39.49698534290028
# Reversed MaxMatch = ['#', 'r', 'ose'] ; LogProb = -38.231318969569
#
# 7 . #longranger
# MaxMatch = ['#', 'long', 'ranger'] ; LogProb = -34.17220309923065
# Reversed MaxMatch = ['#', 'l', 'on', 'granger'] ; LogProb = -44.210519025807024
#
# 8 . #blogtourambiente
# MaxMatch = ['#', 'blo', 'g', 'tour', 'ambient', 'e'] ; LogProb = -73.45880168797089
# Reversed MaxMatch = ['#', 'b', 'log', 'tou', 'ram', 'bien', 'te'] ; LogProb = -88.81464033655092
#
# 9 . #1stsundayofoctober
# MaxMatch = ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r'] ; LogProb = -92.35806430120746
# Reversed MaxMatch = ['#', '1', 'st', 'sunday', 'of', 'october'] ; LogProb = -58.441782784356064
#
# 10 . #grandmarnier
# MaxMatch = ['#', 'grandma', 'r', 'ni', 'er'] ; LogProb = -63.522190662230095
# Reversed MaxMatch = ['#', 'grand', 'm', 'arni', 'er'] ; LogProb = -63.09977599580816
#
# 11 . #pmattheashes
# MaxMatch = ['#', 'p', 'matt', 'he', 'ash', 'es'] ; LogProb = -66.41057858393789
# Reversed MaxMatch = ['#', 'p', 'mat', 'the', 'ash', 'es'] ; LogProb = -64.01345475076978
#
# 12 . #vegan
# MaxMatch = ['#', 'vega', 'n'] ; LogProb = -38.231318969569
# Reversed MaxMatch = ['#', 'v', 'e', 'g', 'an'] ; LogProb = -51.71871148269113
#
# 13 . #movies
# MaxMatch = ['#', 'movie', 's'] ; LogProb = -35.358189018107346
# Reversed MaxMatch = ['#', 'mo', 'vi', 'es'] ; LogProb = -55.85984426565725
#
# 14 . #makingemuklajawabnya
# MaxMatch = ['#', 'maki', 'n', 'gem', 'u', 'k', 'la', 'jawab', 'n', 'ya'] ; LogProb = -120.09641870177987
# Reversed MaxMatch = ['#', 'ma', 'king', 'emu', 'k', 'la', 'jawab', 'n', 'ya'] ; LogProb = -106.55913296259263
#
# 15 . #lovevibes
# MaxMatch = ['#', 'love', 'vi', 'be', 's'] ; LogProb = -52.48196820280953
# Reversed MaxMatch = ['#', 'love', 'vi', 'b', 'es'] ; LogProb = -59.71463317219662
#
# 16 . #1yearofalmostisneverenough
# MaxMatch = ['#', '1', 'year', 'of', 'almost', 'i', 's', 'never', 'enough'] ; LogProb = -72.05196788151108
# Reversed MaxMatch = ['#', '1', 'year', 'of', 'al', 'm', 'os', 'ti', 's', 'never', 'enough'] ; LogProb = -107.12471143837577
#
# 17 . #thedisadvantagesofakindle
# MaxMatch = ['#', 'the', 'disadvantage', 'sofa', 'kindle'] ; LogProb = -55.11361113547543
# Reversed MaxMatch = ['#', 'the', 'di', 'sad', 'van', 'tag', 'es', 'of', 'akindle'] ; LogProb = -92.0188765919814
#
# 18 . #startuphub
# MaxMatch = ['#', 'start', 'up', 'hub'] ; LogProb = -40.78665143029154
# Reversed MaxMatch = ['#', 'star', 'tup', 'hub'] ; LogProb = -50.116841077847766
#
# 19 . #stopcomplaining
# MaxMatch = ['#', 'stop', 'complain', 'ing'] ; LogProb = -48.579147070272505
# Reversed MaxMatch = ['#', 'stop', 'c', 'om', 'p', 'lai', 'ning'] ; LogProb = -83.81112853749536
#
# 20 . #bettybooppose
# MaxMatch = ['#', 'betty', 'boo', 'p', 'pose'] ; LogProb = -60.91665602465348
# Reversed MaxMatch = ['#', 'betty', 'bo', 'oppose'] ; LogProb = -51.007814001737636
#
# 21 . #8thannualpubcrawl
# MaxMatch = ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl'] ; LogProb = -89.76895477902295
# Reversed MaxMatch = ['#', '8', 'th', 'annual', 'pub', 'crawl'] ; LogProb = -71.39559928556982
#
# 22 . #thankyoulord
# MaxMatch = ['#', 'thank', 'youl', 'or', 'd'] ; LogProb = -53.93756100901593
# Reversed MaxMatch = ['#', 'thank', 'you', 'lord'] ; LogProb = -39.6079009970788
#
# 23 . #cbcolympics
# MaxMatch = ['#', 'c', 'b', 'coly', 'm', 'pic', 's'] ; LogProb = -82.31857785084836
# Reversed MaxMatch = ['#', 'c', 'b', 'c', 'olympic', 's'] ; LogProb = -64.3033597914621
#
# 24 . #southampton
# MaxMatch = ['#', 'south', 'a', 'm', 'p', 'ton'] ; LogProb = -58.437168574637525
# Reversed MaxMatch = ['#', 's', 'out', 'ham', 'p', 'ton'] ; LogProb = -63.026947702741346
#
# 25 . #pechanga
# MaxMatch = ['#', 'pech', 'an', 'ga'] ; LogProb = -46.93958885074916
# Reversed MaxMatch = ['#', 'pe', 'changa'] ; LogProb = -41.201733435138706
#
# 26 . #walking
# MaxMatch = ['#', 'walk', 'ing'] ; LogProb = -37.27976009885739
# Reversed MaxMatch = ['#', 'w', 'al', 'king'] ; LogProb = -46.32135188867557
#
# 27 . #ariona
# MaxMatch = ['#', 'arion', 'a'] ; LogProb = -31.84314548670232
# Reversed MaxMatch = ['#', 'a', 'ri', 'ona'] ; LogProb = -45.80810913666092
#
# 28 . #usydoweek
# MaxMatch = ['#', 'u', 'syd', 'owe', 'e', 'k'] ; LogProb = -72.64135679073337
# Reversed MaxMatch = ['#', 'u', 's', 'y', 'do', 'week'] ; LogProb = -63.38488801375665
#
# 29 . #oilandgas
# MaxMatch = ['#', 'oil', 'and', 'gas'] ; LogProb = -36.42032197769561
# Reversed MaxMatch = ['#', 'o', 'i', 'land', 'gas'] ; LogProb = -47.985070474612336
#
# 30 . #melbourne
# MaxMatch = ['#', 'mel', 'bourn', 'e'] ; LogProb = -49.255900441056774
# Reversed MaxMatch = ['#', 'm', 'elb', 'our', 'ne'] ; LogProb = -57.912390189967404
#
# 31 . #thewalkingdead
# MaxMatch = ['#', 'thew', 'alk', 'ing', 'dead'] ; LogProb = -64.66002366405148
# Reversed MaxMatch = ['#', 'thew', 'al', 'king', 'dead'] ; LogProb = -56.91329075629786
#
# 32 . #fries
# MaxMatch = ['#', 'f', 'rie', 's'] ; LogProb = -49.113432137083876
# Reversed MaxMatch = ['#', 'f', 'ri', 'es'] ; LogProb = -52.248926353013026
#
# 33 . #starving
# MaxMatch = ['#', 'star', 'vi', 'n', 'g'] ; LogProb = -60.069938109767655
# Reversed MaxMatch = ['#', 'star', 'v', 'ing'] ; LogProb = -49.269543217460566
#
# 34 . #yiamas
# MaxMatch = ['#', 'yi', 'ama', 's'] ; LogProb = -52.031202869168155
# Reversed MaxMatch = ['#', 'yi', 'a', 'm', 'as'] ; LogProb = -48.0505528450796
#
# 35 . #cumannanya
# MaxMatch = ['#', 'cum', 'anna', 'n', 'ya'] ; LogProb = -62.47236853773141
# Reversed MaxMatch = ['#', 'c', 'u', 'mannan', 'ya'] ; LogProb = -60.77229335119238
#
# 36 . #instagood
# MaxMatch = ['#', 'in', 'stag', 'o', 'od'] ; LogProb = -54.36350339488304
# Reversed MaxMatch = ['#', 'in', 's', 'ta', 'good'] ; LogProb = -50.027746954024494
#
# 37 . #palacefansinthemorning
# MaxMatch = ['#', 'palace', 'fan', 'sin', 'them', 'or', 'ning'] ; LogProb = -71.32384371071944
# Reversed MaxMatch = ['#', 'palace', 'fan', 'sin', 'the', 'morning'] ; LogProb = -56.680355345107145
#
# 38 . #mtlnewtech
# MaxMatch = ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h'] ; LogProb = -87.80370905513715
# Reversed MaxMatch = ['#', 'm', 't', 'l', 'new', 'tech'] ; LogProb = -64.16940712334873
#
# 39 . #ahimacon14
# MaxMatch = ['#', 'ah', 'ima', 'con', '1', '4'] ; LogProb = -66.97302589806905
# Reversed MaxMatch = ['#', 'a', 'hi', 'macon', '1', '4'] ; LogProb = -58.5808784651923
#
# 40 . #skeemsaam
# MaxMatch = ['#', 'skee', 'm', 'saa', 'm'] ; LogProb = -64.15838294986257
# Reversed MaxMatch = ['#', 's', 'k', 'e', 'em', 's', 'aam'] ; LogProb = -83.76285186588397
#
# 41 . #socal
# MaxMatch = ['#', 'soc', 'al'] ; LogProb = -38.63678407767717
# Reversed MaxMatch = ['#', 'so', 'cal'] ; LogProb = -33.60785559053359
#
# 42 . #rosegold
# MaxMatch = ['#', 'ro', 'segol', 'd'] ; LogProb = -51.928018632932925
# Reversed MaxMatch = ['#', 'r', 'ose', 'gold'] ; LogProb = -48.225990705975484
#
# 43 . #txlege
# MaxMatch = ['#', 't', 'x', 'leg', 'e'] ; LogProb = -54.9044025784356
# Reversed MaxMatch = ['#', 't', 'x', 'le', 'ge'] ; LogProb = -58.888849599275304
#
# 44 . #bored
# MaxMatch = ['#', 'bore', 'd'] ; LogProb = -34.74417915810612
# Reversed MaxMatch = ['#', 'bo', 'red'] ; LogProb = -35.91346640444417
#
# 45 . #makeupfree
# MaxMatch = ['#', 'make', 'up', 'free'] ; LogProb = -36.075959451328934
# Reversed MaxMatch = ['#', 'ma', 'keup', 'free'] ; LogProb = -47.30343036108773
#
# 46 . #alliswell
# MaxMatch = ['#', 'all', 'i', 'swell'] ; LogProb = -37.22370833023027
# Reversed MaxMatch = ['#', 'al', 'li', 'swell'] ; LogProb = -50.522306185955934
#
# 47 . #nced
# MaxMatch = ['#', 'n', 'ce', 'd'] ; LogProb = -48.264456986803275
# Reversed MaxMatch = ['#', 'n', 'c', 'ed'] ; LogProb = -44.753204245179084
#
# 48 . #google
# MaxMatch = ['#', 'goo', 'g', 'le'] ; LogProb = -50.31858072049882
# Reversed MaxMatch = ['#', 'go', 'ogle'] ; LogProb = -35.45393407506573
#
# 49 . #siberuang
# MaxMatch = ['#', 'sib', 'er', 'uang'] ; LogProb = -55.85984426565725
# Reversed MaxMatch = ['#', 'si', 'ber', 'uang'] ; LogProb = -55.166697085097304
#
# 50 . #ritenow
# MaxMatch = ['#', 'rite', 'now'] ; LogProb = -32.516064093750565
# Reversed MaxMatch = ['#', 'rit', 'enow'] ; LogProb = -41.89488061569865
#
# 51 . #endomondo
# MaxMatch = ['#', 'end', 'om', 'on', 'do'] ; LogProb = -47.77436374407923
# Reversed MaxMatch = ['#', 'en', 'do', 'mon', 'do'] ; LogProb = -52.6158672389284
#
# 52 . #hungergames
# MaxMatch = ['#', 'hunger', 'game', 's'] ; LogProb = -45.0136967262269
# Reversed MaxMatch = ['#', 'hunger', 'gam', 'es'] ; LogProb = -52.96947250776108
#
# 53 . #harimaumalaya
# MaxMatch = ['#', 'ha', 'rima', 'um', 'ala', 'ya'] ; LogProb = -79.47228861911336
# Reversed MaxMatch = ['#', 'ha', 'ri', 'mau', 'mala', 'ya'] ; LogProb = -81.08172653154746
#
# 54 . #vscocam
# MaxMatch = ['#', 'v', 's', 'coca', 'm'] ; LogProb = -60.52389756781443
# Reversed MaxMatch = ['#', 'v', 's', 'co', 'cam'] ; LogProb = -60.87220426208265
#
# 55 . #startupfest
# MaxMatch = ['#', 'start', 'up', 'fest'] ; LogProb = -43.271558080079544
# Reversed MaxMatch = ['#', 'star', 'tup', 'fest'] ; LogProb = -52.60174772763577
#
# 56 . #fotografías
# MaxMatch = ['#', 'fot', 'og', 'ra', 'f', 'í', 'as'] ; LogProb = -84.56137213663203
# Reversed MaxMatch = ['#', 'f', 'oto', 'gra', 'f', 'í', 'as'] ; LogProb = -81.64360140454775
#
# 57 . #weare90s
# MaxMatch = ['#', 'wear', 'e', '9', '0', 's'] ; LogProb = -66.07856256923942
# Reversed MaxMatch = ['#', 'wea', 're', '9', '0', 's'] ; LogProb = -71.98935921327995
#
# 58 . #instaframeplus
# MaxMatch = ['#', 'in', 'st', 'a', 'frame', 'plus'] ; LogProb = -55.161849249217234
# Reversed MaxMatch = ['#', 'in', 's', 'ta', 'frame', 'plus'] ; LogProb = -62.07809016228441
#
# 59 . #graduated
# MaxMatch = ['#', 'graduate', 'd'] ; LogProb = -34.52906777848918
# Reversed MaxMatch = ['#', 'grad', 'u', 'a', 'ted'] ; LogProb = -53.95596334901546
#
# 60 . #difd
# MaxMatch = ['#', 'di', 'f', 'd'] ; LogProb = -45.18160650435955
# Reversed MaxMatch = ['#', 'd', 'if', 'd'] ; LogProb = -40.30043500965384
#
# 61 . #canadaelections
# MaxMatch = ['#', 'canada', 'election', 's'] ; LogProb = -44.81229316154909
# Reversed MaxMatch = ['#', 'cana', 'dae', 'le', 'c', 'ti', 'ons'] ; LogProb = -89.54952712328364
#
# 62 . #askolly
# MaxMatch = ['#', 'ask', 'o', 'l', 'ly'] ; LogProb = -58.835947023552784
# Reversed MaxMatch = ['#', 'as', 'kol', 'ly'] ; LogProb = -46.970535945814404
#
# 63 . #cornell
# MaxMatch = ['#', 'cornel', 'l'] ; LogProb = -39.061667271642435
# Reversed MaxMatch = ['#', 'cor', 'nell'] ; LogProb = -41.201733435138706
#
# 64 . #toronto
# MaxMatch = ['#', 'toro', 'n', 'to'] ; LogProb = -42.02433404098681
# Reversed MaxMatch = ['#', 'tor', 'onto'] ; LogProb = -37.78400675152534
#
# 65 . #statoftheday
# MaxMatch = ['#', 'st', 'at', 'oft', 'he', 'day'] ; LogProb = -58.80950730747736
# Reversed MaxMatch = ['#', 's', 'tat', 'of', 'the', 'day'] ; LogProb = -51.76881492449543
#
# 66 . #vegetables
# MaxMatch = ['#', 'vegetable', 's'] ; LogProb = -36.36149112697113
# Reversed MaxMatch = ['#', 'v', 'e', 'ge', 'tab', 'l', 'es'] ; LogProb = -86.08399615951527
#
# 67 . #foodporn
# MaxMatch = ['#', 'food', 'po', 'r', 'n'] ; LogProb = -56.80732689139165
# Reversed MaxMatch = ['#', 'food', 'p', 'or', 'n'] ; LogProb = -48.47572521263703
#
# 68 . #grammyfans
# MaxMatch = ['#', 'gram', 'my', 'fan', 's'] ; LogProb = -54.16235201736372
# Reversed MaxMatch = ['#', 'g', 'rammy', 'fan', 's'] ; LogProb = -60.91166309882319
#
# 69 . #blackhat
# MaxMatch = ['#', 'black', 'hat'] ; LogProb = -32.533709354019884
# Reversed MaxMatch = ['#', 'b', 'lac', 'khat'] ; LogProb = -51.19640517154518
#
# 70 . #chargers
# MaxMatch = ['#', 'charger', 's'] ; LogProb = -38.759386399769504
# Reversed MaxMatch = ['#', 'char', 'gers'] ; LogProb = -41.201733435138706
#
# 71 . #reachingyougpeople
# MaxMatch = ['#', 'reach', 'ing', 'you', 'g', 'people'] ; LogProb = -61.45251308502527
# Reversed MaxMatch = ['#', 'rea', 'ching', 'yo', 'ug', 'people'] ; LogProb = -75.25513662762971
#
# 72 . #urbangardening
# MaxMatch = ['#', 'urban', 'gardenin', 'g'] ; LogProb = -49.26543080590747
# Reversed MaxMatch = ['#', 'urban', 'gar', 'de', 'ning'] ; LogProb = -61.251425166909016
#
# 73 . #meetup
# MaxMatch = ['#', 'meet', 'up'] ; LogProb = -29.339384252943937
# Reversed MaxMatch = ['#', 'me', 'e', 'tup'] ; LogProb = -45.0713090009869
#
# 74 . #imsosore
# MaxMatch = ['#', 'i', 'm', 'soso', 're'] ; LogProb = -57.05564155124515
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'sore'] ; LogProb = -48.45016279496156
#
# 75 . #nevergetsold
# MaxMatch = ['#', 'never', 'get', 'sol', 'd'] ; LogProb = -51.33839733483806
# Reversed MaxMatch = ['#', 'never', 'get', 's', 'old'] ; LogProb = -47.02575755681611
#
# 76 . #fried
# MaxMatch = ['#', 'f', 'rie', 'd'] ; LogProb = -48.3171007202887
# Reversed MaxMatch = ['#', 'f', 'ri', 'ed'] ; LogProb = -49.60986902339776
#
# 77 . #getfreetattooaviciipasses
# MaxMatch = ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passe', 's'] ; LogProb = -99.78200339872195
# Reversed MaxMatch = ['#', 'get', 'free', 'tattoo', 'a', 'vic', 'i', 'i', 'pass', 'es'] ; LogProb = -94.20860402245906
#
# 78 . #flambees
# MaxMatch = ['#', 'flamb', 'e', 'es'] ; LogProb = -52.14627219895294
# Reversed MaxMatch = ['#', 'flam', 'be', 'es'] ; LogProb = -47.09923441808725
#
# 79 . #jordaan
# MaxMatch = ['#', 'jo', 'r', 'da', 'an'] ; LogProb = -53.21564088620211
# Reversed MaxMatch = ['#', 'j', 'or', 'da', 'an'] ; LogProb = -48.534697448741234
#
# 80 . #ladygaga
# MaxMatch = ['#', 'lady', 'gag', 'a'] ; LogProb = -39.80422206955438
# Reversed MaxMatch = ['#', 'lady', 'g', 'aga'] ; LogProb = -48.632181766928596
#
# 81 . #cdnpoli
# MaxMatch = ['#', 'c', 'd', 'n', 'pol', 'i'] ; LogProb = -62.840708027508704
# Reversed MaxMatch = ['#', 'c', 'd', 'n', 'po', 'li'] ; LogProb = -70.6972212285025
#
# 82 . #crepes
# MaxMatch = ['#', 'crepe', 's'] ; LogProb = -38.06623921920956
# Reversed MaxMatch = ['#', 'c', 're', 'pes'] ; LogProb = -49.6695288598041
#
# 83 . #arte
# MaxMatch = ['#', 'art', 'e'] ; LogProb = -32.83897429702953
# Reversed MaxMatch = ['#', 'ar', 'te'] ; LogProb = -41.89488061569865
#
# 84 . #takeabreak
# MaxMatch = ['#', 'take', 'ab', 'reak'] ; LogProb = -48.058452945365765
# Reversed MaxMatch = ['#', 'ta', 'kea', 'break'] ; LogProb = -51.37120789592511
#
# 85 . #rainorshine
# MaxMatch = ['#', 'rain', 'or', 'shine'] ; LogProb = -41.460899835797356
# Reversed MaxMatch = ['#', 'r', 'ai', 'nor', 'shine'] ; LogProb = -58.39822668282683
#
# 86 . #booyaa
# MaxMatch = ['#', 'boo', 'ya', 'a'] ; LogProb = -43.505524043666874
# Reversed MaxMatch = ['#', 'boo', 'y', 'aa'] ; LogProb = -52.6817904353093
#
# 87 . #peperoni
# MaxMatch = ['#', 'pep', 'er', 'on', 'i'] ; LogProb = -52.459037360627256
# Reversed MaxMatch = ['#', 'pe', 'pe', 'ro', 'ni'] ; LogProb = -68.43851527685511
#
# 88 . #thenext5goldenyears
# MaxMatch = ['#', 'then', 'ex', 't', '5', 'golden', 'year', 's'] ; LogProb = -80.68356932390877
# Reversed MaxMatch = ['#', 'the', 'next', '5', 'golden', 'year', 's'] ; LogProb = -62.26974684738264
#
# 89 . #beringmy
# MaxMatch = ['#', 'beri', 'n', 'g', 'my'] ; LogProb = -56.14340549507182
# Reversed MaxMatch = ['#', 'be', 'ring', 'my'] ; LogProb = -36.04340425446204
#
# 90 . #scifigeek
# MaxMatch = ['#', 's', 'c', 'if', 'i', 'geek'] ; LogProb = -59.604843099878764
# Reversed MaxMatch = ['#', 's', 'c', 'i', 'fi', 'geek'] ; LogProb = -67.30060109043353
#
# 91 . #blessedmorethanicanimagine
# MaxMatch = ['#', 'bless', 'ed', 'more', 'than', 'i', 'can', 'imagine'] ; LogProb = -71.42686214385067
# Reversed MaxMatch = ['#', 'b', 'l', 'essed', 'more', 'th', 'ani', 'can', 'imagine'] ; LogProb = -97.77840188497012
#
# 92 . #uptonogood
# MaxMatch = ['#', 'up', 'ton', 'og', 'o', 'od'] ; LogProb = -70.31002146837163
# Reversed MaxMatch = ['#', 'up', 'to', 'no', 'good'] ; LogProb = -37.7461152144899
#
# 93 . #lotsoflove
# MaxMatch = ['#', 'lot', 'so', 'flo', 'v', 'e'] ; LogProb = -64.29809204724542
# Reversed MaxMatch = ['#', 'lot', 's', 'of', 'love'] ; LogProb = -45.88786665373828
#
# 94 . #mamajeanneandme
# MaxMatch = ['#', 'mam', 'a', 'jeanne', 'and', 'me'] ; LogProb = -56.39307449518158
# Reversed MaxMatch = ['#', 'm', 'ama', 'jeanne', 'and', 'me'] ; LogProb = -62.91844909956175
#
# 95 . #realgoodbikes
# MaxMatch = ['#', 'real', 'good', 'bike', 's'] ; LogProb = -54.43916369207636
# Reversed MaxMatch = ['#', 'real', 'good', 'bi', 'k', 'es'] ; LogProb = -68.04311744121371
#
# 96 . #askherforfback
# MaxMatch = ['#', 'ask', 'her', 'for', 'f', 'back'] ; LogProb = -51.26822856354076
# Reversed MaxMatch = ['#', 'ask', 'her', 'f', 'orf', 'back'] ; LogProb = -60.42622245514473
#
# 97 . #boomtaob
# MaxMatch = ['#', 'boom', 'tao', 'b'] ; LogProb = -47.38974268177486
# Reversed MaxMatch = ['#', 'boom', 'ta', 'ob'] ; LogProb = -53.66261968832103
#
# 98 . #confused
# MaxMatch = ['#', 'confuse', 'd'] ; LogProb = -36.171295513746266
# Reversed MaxMatch = ['#', 'con', 'fu', 's', 'ed'] ; LogProb = -61.970816550750754
#
# 99 . #breedingground
# MaxMatch = ['#', 'breed', 'ing', 'ground'] ; LogProb = -47.7383638909065
# Reversed MaxMatch = ['#', 'b', 'reeding', 'ground'] ; LogProb = -45.965296554690596
#
# 100 . #instalook
# MaxMatch = ['#', 'in', 'st', 'alo', 'ok'] ; LogProb = -58.064805368995536
# Reversed MaxMatch = ['#', 'in', 's', 'ta', 'look'] ; LogProb = -50.72960607518646
#
# 101 . #hometomama
# MaxMatch = ['#', 'home', 'toma', 'ma'] ; LogProb = -46.557836705155246
# Reversed MaxMatch = ['#', 'home', 'tom', 'ama'] ; LogProb = -44.70153871478961
#
# 102 . #potd
# MaxMatch = ['#', 'pot', 'd'] ; LogProb = -34.59575915298785
# Reversed MaxMatch = ['#', 'po', 'td'] ; LogProb = -41.201733435138706
#
# 103 . #learningcommunties
# MaxMatch = ['#', 'learn', 'ing', 'co', 'm', 'munt', 'ie', 's'] ; LogProb = -99.51659780335716
# Reversed MaxMatch = ['#', 'lear', 'ning', 'c', 'om', 'mun', 'ti', 'es'] ; LogProb = -104.6131099513336
#
# 104 . #burgers
# MaxMatch = ['#', 'burg', 'er', 's'] ; LogProb = -52.7243500497281
# Reversed MaxMatch = ['#', 'bur', 'gers'] ; LogProb = -41.89488061569865
#
# 105 . #taintedlove
# MaxMatch = ['#', 'taint', 'ed', 'love'] ; LogProb = -47.08090238381573
# Reversed MaxMatch = ['#', 'tain', 'ted', 'love'] ; LogProb = -48.3336653523111
#
# 106 . #strictlyus
# MaxMatch = ['#', 'strictly', 'u', 's'] ; LogProb = -46.55893219549668
# Reversed MaxMatch = ['#', 'strict', 'l', 'yus'] ; LogProb = -50.54172427181303
#
# 107 . #givesmehope
# MaxMatch = ['#', 'give', 's', 'me', 'hope'] ; LogProb = -48.46642193466403
# Reversed MaxMatch = ['#', 'gi', 'v', 'es', 'me', 'hope'] ; LogProb = -68.20082547421634
#
# 108 . #focusateneo
# MaxMatch = ['#', 'focus', 'aten', 'e', 'o'] ; LogProb = -59.101828638562054
# Reversed MaxMatch = ['#', 'fo', 'c', 'u', 'sate', 'neo'] ; LogProb = -76.34669835830115
#
# 109 . #imsobored
# MaxMatch = ['#', 'i', 'm', 'sob', 'ore', 'd'] ; LogProb = -68.47507737431539
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'bo', 'red'] ; LogProb = -58.83161095118012
#
# 110 . #butitsalsokindofaphone
# MaxMatch = ['#', 'but', 'it', 'sal', 'sok', 'ind', 'of', 'a', 'phone'] ; LogProb = -82.96646587046082
# Reversed MaxMatch = ['#', 'bu', 'tit', 's', 'also', 'kin', 'do', 'fa', 'phone'] ; LogProb = -103.24965789510391
#
# 111 . #workmates
# MaxMatch = ['#', 'work', 'mate', 's'] ; LogProb = -42.99604956508533
# Reversed MaxMatch = ['#', 'work', 'mat', 'es'] ; LogProb = -47.43082676514474
#
# 112 . #shopaholic
# MaxMatch = ['#', 'shop', 'aho', 'li', 'c'] ; LogProb = -60.86190550988207
# Reversed MaxMatch = ['#', 'sho', 'paho', 'li', 'c'] ; LogProb = -65.02078859324175
#
# 113 . #goingout
# MaxMatch = ['#', 'goi', 'n', 'gout'] ; LogProb = -51.09767033085949
# Reversed MaxMatch = ['#', 'go', 'in', 'gout'] ; LogProb = -38.35204063660481
#
# 114 . #wearesocial
# MaxMatch = ['#', 'wear', 'es', 'o', 'c', 'i', 'al'] ; LogProb = -74.26361178091013
# Reversed MaxMatch = ['#', 'wea', 're', 'social'] ; LogProb = -48.53075052941066
#
# 115 . #photoby
# MaxMatch = ['#', 'photo', 'by'] ; LogProb = -31.5263391636427
# Reversed MaxMatch = ['#', 'pho', 'toby'] ; LogProb = -41.89488061569865
#
# 116 . #swedumtl
# MaxMatch = ['#', 's', 'wed', 'um', 't', 'l'] ; LogProb = -70.7563101448725
# Reversed MaxMatch = ['#', 's', 'we', 'dum', 't', 'l'] ; LogProb = -65.58091399183698
#
# 117 . #blessedsunday
# MaxMatch = ['#', 'bless', 'ed', 'sunday'] ; LogProb = -46.29322902976367
# Reversed MaxMatch = ['#', 'b', 'l', 'essed', 'sunday'] ; LogProb = -57.703184386522445
#
# 118 . #uniexamonasaturday
# MaxMatch = ['#', 'unie', 'x', 'a', 'monasa', 'turd', 'ay'] ; LogProb = -84.93042169844293
# Reversed MaxMatch = ['#', 'u', 'ni', 'ex', 'a', 'mona', 'saturday'] ; LogProb = -79.74583309722324
#
# 119 . #allwedoiscurls
# MaxMatch = ['#', 'all', 'wed', 'o', 'i', 'scur', 'l', 's'] ; LogProb = -84.79986498065594
# Reversed MaxMatch = ['#', 'all', 'w', 'edo', 'i', 's', 'curl', 's'] ; LogProb = -86.00166150555928
#
# 120 . #innoretail
# MaxMatch = ['#', 'inn', 'ore', 'tail'] ; LogProb = -50.338383347795
# Reversed MaxMatch = ['#', 'in', 'no', 'retail'] ; LogProb = -35.178515920166525
#
# 121 . #aflpowertigers
# MaxMatch = ['#', 'a', 'f', 'l', 'power', 'tiger', 's'] ; LogProb = -70.20621295920735
# Reversed MaxMatch = ['#', 'a', 'f', 'l', 'power', 'ti', 'gers'] ; LogProb = -74.72800153625639
#
# 122 . #lebedeintennis
# MaxMatch = ['#', 'le', 'bed', 'e', 'in', 'tennis'] ; LogProb = -59.77529067893235
# Reversed MaxMatch = ['#', 'le', 'be', 'de', 'in', 'tennis'] ; LogProb = -54.76809880661386
#
# 123 . #loadsoffun
# MaxMatch = ['#', 'load', 'so', 'f', 'fun'] ; LogProb = -50.98470999446624
# Reversed MaxMatch = ['#', 'load', 's', 'of', 'fun'] ; LogProb = -48.55133040306479
#
# 124 . #panthers
# MaxMatch = ['#', 'panther', 's'] ; LogProb = -38.06623921920956
# Reversed MaxMatch = ['#', 'pant', 'hers'] ; LogProb = -39.061667271642435
#
# 125 . #anferneehardaway
# MaxMatch = ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay'] ; LogProb = -96.88866403011228
# Reversed MaxMatch = ['#', 'an', 'f', 'er', 'nee', 'hard', 'away'] ; LogProb = -74.47883003275068
#
# 126 . #excitables
# MaxMatch = ['#', 'excitable', 's'] ; LogProb = -38.759386399769504
# Reversed MaxMatch = ['#', 'ex', 'c', 'i', 'tab', 'l', 'es'] ; LogProb = -79.77609131010777
#
# 127 . #grilled
# MaxMatch = ['#', 'grille', 'd'] ; LogProb = -36.57676062185443
# Reversed MaxMatch = ['#', 'grill', 'ed'] ; LogProb = -36.690873928621855
#
# 128 . #singapore
# MaxMatch = ['#', 'sing', 'a', 'pore'] ; LogProb = -41.15414878650339
# Reversed MaxMatch = ['#', 's', 'inga', 'pore'] ; LogProb = -51.62573776105999
#
# 129 . #tcschleissheim
# MaxMatch = ['#', 't', 'c', 's', 'c', 'h', 'lei', 's', 'she', 'i', 'm'] ; LogProb = -110.85904464427662
# Reversed MaxMatch = ['#', 't', 'c', 's', 'c', 'h', 'lei', 's', 's', 'hei', 'm'] ; LogProb = -124.23213730295133
#
# 130 . #wok
# MaxMatch = ['#', 'wo', 'k'] ; LogProb = -39.49698534290028
# Reversed MaxMatch = ['#', 'w', 'ok'] ; LogProb = -38.31136167724254
#
# 131 . #sinvsmas
# MaxMatch = ['#', 'sin', 'v', 'sma', 's'] ; LogProb = -59.36812686530637
# Reversed MaxMatch = ['#', 'sin', 'v', 's', 'm', 'as'] ; LogProb = -61.61057229608198
#
# 132 . #bedimages
# MaxMatch = ['#', 'bedim', 'age', 's'] ; LogProb = -47.29500442077366
# Reversed MaxMatch = ['#', 'be', 'di', 'mag', 'es'] ; LogProb = -57.2355583939159
#
# 133 . #ididntchoosethestudentlifeitchoseme
# MaxMatch = ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me'] ; LogProb = -143.10614091129415
# Reversed MaxMatch = ['#', 'i', 'didnt', 'choose', 'the', 'student', 'life', 'it', 'cho', 'seme'] ; LogProb = -95.47777845737151
#
# 134 . #fotorus
# MaxMatch = ['#', 'fot', 'or', 'u', 's'] ; LogProb = -55.70575300884007
# Reversed MaxMatch = ['#', 'fo', 'torus'] ; LogProb = -41.89488061569865
#
# 135 . #olah
# MaxMatch = ['#', 'o', 'la', 'h'] ; LogProb = -45.41566165575285
# Reversed MaxMatch = ['#', 'o', 'l', 'ah'] ; LogProb = -46.595299839667554
#
# 136 . #bringithomemy
# MaxMatch = ['#', 'bring', 'it', 'home', 'my'] ; LogProb = -42.18693566342307
# Reversed MaxMatch = ['#', 'brin', 'git', 'home', 'my'] ; LogProb = -54.72446728587557

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this (but if you don't want to use sklearn that's fine).
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

x_train, x_dev, x_test = None, None, None
y_train, y_dev, y_test = None, None, None

###
# Your answer BEGINS HERE
###

# first_partition = round(len(x_processed)*0.7)
# x_train = x_processed[:first_partition]
# second_partition = round((len(x_processed) - first_partition)/2)
# x_dev = x_processed[first_partition:(first_partition+second_partition)]
# x_test = x_processed[:second_partition]

x_train, x_test, y_train, y_test = train_test_split(x_processed, y_processed, test_size=0.3, train_size=0.7, random_state = None, stratify=y)

y=None

x_dev, x_test, y_dev, y_test = train_test_split(x_test, y_test, test_size=0.5, train_size=0.5, random_state = None, stratify=y)
#print(len(y_test))

vectorizer = DictVectorizer()
x_train = vectorizer.fit_transform(x_train)
x_dev = vectorizer.transform(x_dev)
x_test = vectorizer.transform(x_test)
#print(vectorizer.get_feature_names())
# y_train = y_processed[:first_partition]
# y_dev = y_processed[first_partition:(first_partition+second_partition)]
# y_test = y_processed[:second_partition]

#print(x_train[0])
#for i in x_test:
    
# print(len(y_train))
# print(len(x_dev))
# print(len(x_test))

###
# Your answer ENDS HERE
###

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

###
# Your answer BEGINS HERE
###
clfs = [MultinomialNB(),LogisticRegression()]

#reference: tutorial worksheet 3
def do_multiple_classifiers(clfs,train_data,train_classifications, test_data, test_classifications):
    for clf in clfs:
        #predictions = model_selection.cross_val_predict(clf, data,classifications, cv=10)
        clf.fit(train_data, train_classifications)
        predictions = clf.predict(test_data)
        print (clf)
        print ("accuracy")
        print (accuracy_score(test_classifications, predictions))
        print (classification_report(test_classifications, predictions))
        print(clf.coef_[0])
        
do_multiple_classifiers(clfs, x_train, y_train, x_dev, y_dev)
    
###
# Your answer ENDS HERE
###
# Out:
# MultinomialNB()
# accuracy
# 0.2907801418439716
#               precision    recall  f1-score   support
#
#           au       0.35      0.38      0.36        21
#           ca       0.38      0.18      0.24        17
#           de       0.00      0.00      0.00         7
#           gb       0.40      0.44      0.42        18
#           id       0.33      0.40      0.36        10
#           my       0.26      0.45      0.33        11
#           ph       0.33      0.21      0.26        19
#           sg       0.33      0.23      0.27        13
#           us       0.11      0.15      0.12        13
#           za       0.22      0.33      0.27        12
#
#     accuracy                           0.29       141
#    macro avg       0.27      0.28      0.26       141
# weighted avg       0.30      0.29      0.28       141
#
# [-7.58095482 -8.274102   -8.274102   ... -8.274102   -8.274102
#  -8.274102  ]
# /home/kali/.local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute coef_ was deprecated in version 0.24 and will be removed in 1.1 (renaming of 0.26).
#   warnings.warn(msg, category=FutureWarning)
# LogisticRegression()
# accuracy
# 0.28368794326241137
#               precision    recall  f1-score   support
#
#           au       0.50      0.19      0.28        21
#           ca       0.10      0.06      0.07        17
#           de       0.00      0.00      0.00         7
#           gb       0.42      0.44      0.43        18
#           id       0.25      0.70      0.37        10
#           my       0.25      0.45      0.32        11
#           ph       0.42      0.26      0.32        19
#           sg       0.30      0.23      0.26        13
#           us       0.12      0.15      0.13        13
#           za       0.31      0.42      0.36        12
#
#     accuracy                           0.28       141
#    macro avg       0.27      0.29      0.25       141
# weighted avg       0.30      0.28      0.27       141
#
# [ 0.21527658 -0.03228219 -0.04182467 ... -0.03622016 -0.01834366
#  -0.01575566]

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
###
# Your answer BEGINS HERE
###
do_multiple_classifiers(clfs, x_train, y_train, x_test, y_test)

###
# Your answer ENDS HERE
###
# Out:
# MultinomialNB()
# accuracy
# 0.28169014084507044
#               precision    recall  f1-score   support
#
#           au       0.25      0.33      0.29         9
#           ca       0.20      0.23      0.21        13
#           de       0.33      0.12      0.18         8
#           gb       0.14      0.25      0.18        12
#           id       0.82      0.45      0.58        20
#           my       0.46      0.32      0.37        19
#           ph       0.44      0.36      0.40        11
#           sg       0.33      0.27      0.30        15
#           us       0.09      0.12      0.10        17
#           za       0.23      0.28      0.25        18
#
#     accuracy                           0.28       142
#    macro avg       0.33      0.27      0.29       142
# weighted avg       0.35      0.28      0.30       142
#
# [-7.58095482 -8.274102   -8.274102   ... -8.274102   -8.274102
#  -8.274102  ]
# /home/kali/.local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute coef_ was deprecated in version 0.24 and will be removed in 1.1 (renaming of 0.26).
#   warnings.warn(msg, category=FutureWarning)
# LogisticRegression()
# accuracy
# 0.3591549295774648
#               precision    recall  f1-score   support
#
#           au       0.38      0.33      0.35         9
#           ca       0.21      0.23      0.22        13
#           de       0.33      0.12      0.18         8
#           gb       0.11      0.17      0.13        12
#           id       0.56      0.75      0.64        20
#           my       0.70      0.37      0.48        19
#           ph       0.44      0.36      0.40        11
#           sg       0.42      0.33      0.37        15
#           us       0.17      0.24      0.20        17
#           za       0.41      0.39      0.40        18
#
#     accuracy                           0.36       142
#    macro avg       0.37      0.33      0.34       142
# weighted avg       0.39      0.36      0.36       142
#
# [ 0.21527658 -0.03228219 -0.04182467 ... -0.03622016 -0.01834366
#  -0.01575566]

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
###
# Your answer BEGINS HERE
###
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import numpy as np

nb = MultinomialNB().fit(x_train, y_train)
lr = LogisticRegression().fit(x_train, y_train)
# print(len(nb.coef_[0]))
# print(nb.coef_[0][0]==nb.coef_[0][2000])
# print(nb.classes_)
# print(len(vectorizer.get_feature_names()))
# print(vectorizer.get_feature_names()[0])

#answer
print("Classifier = Logistic Regression")
print('')
# for i in range(len(lr.classes_)):
#     print('Country = ', lg.classes_[i])
#     middle={}
#     for j in range(len(lr.coef_[i])):
#         middle[lr.coef_[i][j]] = vectorizer.get_feature_names()[j]

for i in range(len(lr.classes_)):
    print('Country = ', lr.classes_[i])
    middle={}
    for j in range(len(lr.coef_[i])):
        #print('nb.coef_[i][j]:', nb.coef_[i][j])
        if lr.coef_[i][j] not in middle:
            middle[lr.coef_[i][j]] = vectorizer.get_feature_names()[j]
        elif lr.coef_[i][j] in middle and isinstance(middle[lr.coef_[i][j]],str):
            middle[lr.coef_[i][j]] = [middle[lr.coef_[i][j]],vectorizer.get_feature_names()[j]]
        else:
            #print('middle[nb.coef_[i][j]]:', middle[nb.coef_[i][j]])
            #print('vectorizer.get_feature_names()[j]:', vectorizer.get_feature_names()[j])
            middle[lr.coef_[i][j]] = middle[lr.coef_[i][j]] + [vectorizer.get_feature_names()[j]]
            #print('middle[nb.coef_[i][j]]_2:',middle[nb.coef_[i][j]])
    #sorted_list = nb.coef_[i].split(' ').sort()
    sorted_list = lr.coef_[i].tolist()
    sorted_list = sorted(sorted_list)
    #print('nb.coef_[i]:',nb.coef_[i])
    #sorted_list = np.char.split(nb.coef_[i]).sort()
    #sorted_list = str(nb.coef_[i]).split(' ').sort()
    #print(np.array(nb.coef_[i][0]))
    #print(np.char.split(str(nb.coef_[i])))
    #print('sorted_list',sorted_list)
    #print('middle:', middle)
    before = []
    result = []
    for l in sorted_list[:20]:
        if isinstance(middle[l], str) and middle[l] not in before:
            #print(middle[l], '(', l, ')')
            result.append(str(middle[l]) + ' ' + '(' + str(l) + ')')
            before.append(middle[l])
        elif isinstance(middle[l], list) and middle[l][0] not in before:
            #print(middle[l][0], '(', l, ')')
            result.append(str(middle[l]) + ' ' + '(' + str(l) + ')')
            before.append(middle[l][0])
        elif isinstance(middle[l], list) and middle[l][0] in before:
            number = 0
            while True:
                if middle[l][number] in before:
                    number = number + 1
                else:
                    #print(middle[l][number], '(', l, ')')
                    result.append(str(middle[l]) + ' ' + '(' + str(l) + ')')
                    before.append(middle[l][number])
                    break
    print(' '.join(result))
    print("")

#Naive Bayes
print("Classifier = Naive Bayes")
print("")
for i in range(len(nb.classes_)):
    print('Country = ', nb.classes_[i])
    middle={}
    for j in range(len(nb.coef_[i])):
        #print('nb.coef_[i][j]:', nb.coef_[i][j])
        if nb.coef_[i][j] not in middle:
            middle[nb.coef_[i][j]] = vectorizer.get_feature_names()[j]
        elif nb.coef_[i][j] in middle and isinstance(middle[nb.coef_[i][j]],str):
            middle[nb.coef_[i][j]] = [middle[nb.coef_[i][j]],vectorizer.get_feature_names()[j]]
        else:
            #print('middle[nb.coef_[i][j]]:', middle[nb.coef_[i][j]])
            #print('vectorizer.get_feature_names()[j]:', vectorizer.get_feature_names()[j])
            middle[nb.coef_[i][j]] = middle[nb.coef_[i][j]] + [vectorizer.get_feature_names()[j]]
            #print('middle[nb.coef_[i][j]]_2:',middle[nb.coef_[i][j]])
    #sorted_list = nb.coef_[i].split(' ').sort()
    sorted_list = nb.coef_[i].tolist()
    sorted_list = sorted(sorted_list)
    #print('nb.coef_[i]:',nb.coef_[i])
    #sorted_list = np.char.split(nb.coef_[i]).sort()
    #sorted_list = str(nb.coef_[i]).split(' ').sort()
    #print(np.array(nb.coef_[i][0]))
    #print(np.char.split(str(nb.coef_[i])))
    #print('sorted_list',sorted_list)
    #print('middle:', middle)
    before = []
    result = []
    #print('sorted_list[:20]:',sorted_list[:20])
    for l in sorted_list[:20]:
        if isinstance(middle[l], str) and middle[l] not in before:
            #print(middle[l], '(', l, ')')
            result.append(str(middle[l]) + ' ' + '(' + str(l) + ')')
            before.append(middle[l])
        elif isinstance(middle[l], list) and middle[l][0] not in before:
            #print(middle[l][0], '(', l, ')')
            result.append(str(middle[l][0]) + ' ' + '(' + str(l) + ')')
            before.append(middle[l][0])
        elif isinstance(middle[l], list) and middle[l][0] in before:
            number = 0
            while True:
                if middle[l][number] in before:
                    number = number + 1
                else:
                    #print(middle[l][number], '(', l, ')')
                    result.append(str(middle[l][number]) + ' ' + '(' + str(l) + ')')
